# %%
from langchain_core.documents import Document
from langchain_chroma import Chroma
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever
from langchain_cohere import CohereRerank

# %%
pip install langchain_cohere
# Out:
# Requirement already satisfied: langchain_cohere in ./venv/lib/python3.14/site-packages (0.6.0)
# Requirement already satisfied: cohere<6.0,>=5.18.0 in ./venv/lib/python3.14/site-packages (from langchain_cohere) (5.21.1)
# Requirement already satisfied: langchain-core<2.0,>=1.2.16 in ./venv/lib/python3.14/site-packages (from langchain_cohere) (1.5.1)
# Requirement already satisfied: pydantic<3,>=2 in ./venv/lib/python3.14/site-packages (from langchain_cohere) (2.12.5)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in ./venv/lib/python3.14/site-packages (from langchain_cohere) (6.0.12.20260724)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in ./venv/lib/python3.14/site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (1.12.2)
# Requirement already satisfied: httpx>=0.21.2 in ./venv/lib/python3.14/site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (0.28.1)
# Requirement already satisfied: pydantic-core>=2.18.2 in ./venv/lib/python3.14/site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (2.41.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in ./venv/lib/python3.14/site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (2.34.2)
# Requirement already satisfied: tokenizers<1,>=0.15 in ./venv/lib/python3.14/site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (0.22.2)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in ./venv/lib/python3.14/site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (2.33.0.20260712)
# Requirement already satisfied: typing_extensions>=4.0.0 in ./venv/lib/python3.14/site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venv/lib/python3.14/site-packages (from langchain-core<2.0,>=1.2.16->langchain_cohere) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in ./venv/lib/python3.14/site-packages (from langchain-core<2.0,>=1.2.16->langchain_cohere) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./venv/lib/python3.14/site-packages (from langchain-core<2.0,>=1.2.16->langchain_cohere) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in ./venv/lib/python3.14/site-packages (from langchain-core<2.0,>=1.2.16->langchain_cohere) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./venv/lib/python3.14/site-packages (from langchain-core<2.0,>=1.2.16->langchain_cohere) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.14/site-packages (from langchain-core<2.0,>=1.2.16->langchain_cohere) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./venv/lib/python3.14/site-packages (from langchain-core<2.0,>=1.2.16->langchain_cohere) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=1.2.16->langchain_cohere) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in ./venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0,>=1.2.16->langchain_cohere) (0.25.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.14/site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.14/site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.14/site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (3.18)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.14/site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=2->langchain_cohere) (0.8.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=2->langchain_cohere) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain_cohere) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain_cohere) (2.7.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in ./venv/lib/python3.14/site-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (1.24.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in ./venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in ./venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (3.32.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in ./venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (1.5.2)
# Requirement already satisfied: tqdm>=4.42.1 in ./venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (4.69.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
chunks = [
    # Tesla - Financial & Production
    "Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.",
    "Tesla's automotive gross margin improved to 19.3% this quarter.",
    "Tesla Cybertruck production ramp begins in 2024 with initial deliveries.",
    "Tesla announced plans to expand Gigafactory production capacity.",
    "Tesla stock price reached new highs following earnings announcement.",
    "Tesla's energy storage business grew 40% year-over-year.",
    "Tesla continues to lead in electric vehicle market share globally.",
    "Tesla Model Y became the best-selling vehicle worldwide.",
    "Tesla reported strong free cash flow generation of $7.5 billion.",
    "Tesla's Full Self-Driving revenue increased significantly.",
    
    # Microsoft - Development & Acquisitions
    "Microsoft acquired GitHub for $7.5 billion in 2018.",
    "Microsoft's cloud revenue Azure grew 29% year-over-year.",
    "Microsoft announced new AI features for Visual Studio Code.",
    "Microsoft Teams integration with GitHub enhances developer workflow.",
    "Microsoft's developer tools division sees strong adoption.",
    "Microsoft acquired Activision Blizzard for $68.7 billion.",
    "Microsoft's productivity suite gained 50 million new users.",
    "Microsoft announced new Surface devices for developers.",
    "Microsoft's AI Copilot features expand to more development tools.",
    "Microsoft's enterprise solutions drive revenue growth.",
    
    # NVIDIA - AI & Hardware
    "NVIDIA's data center revenue reached $47.5 billion annually.",
    "NVIDIA's H100 GPUs see unprecedented demand for AI training.",
    "NVIDIA announced next-generation Blackwell architecture.",
    "NVIDIA's gaming revenue declined due to crypto market changes.",
    "NVIDIA's automotive AI platform partnerships expanded.",
    "NVIDIA's AI chip shortage affects cloud providers.",
    "NVIDIA stock valuation exceeds $2 trillion market cap.",
    "NVIDIA's CUDA platform dominates AI development.",
    "NVIDIA announced new AI inference chips for edge computing.",
    "NVIDIA's partnership with major cloud providers strengthens.",
    # Google/Alphabet - AI & Cloud
    "Google's AI investments total over $100 billion in recent years.",
    "Google Cloud revenue grew 35% reaching $8.4 billion quarterly.",
    "Google announced Gemini AI model competing with GPT-4.",
    "Google's search advertising revenue remains strong at $59 billion.",
    "Google's Workspace products integrate advanced AI features.",
    "Google announced quantum computing breakthroughs.",
    "Google's autonomous vehicle division Waymo expands operations.",
    "Google's AI research published breakthrough papers.",
    "Google's cloud AI services see enterprise adoption.",
    "Google faces regulatory scrutiny over AI dominance.",
    
    # Noisy/Less Relevant Chunks
    "The Tesla coil was invented by Nikola Tesla in 1891.",
    "Microsoft Excel spreadsheet formulas can be complex for beginners.",
    "NVIDIA Shield TV streaming device gets software update.",
    "Google Maps navigation improved with real-time traffic data.",
    "Production delays affected multiple manufacturing sectors.",
    "Financial markets showed volatility during earnings season.",
    "Revenue recognition standards changed for software companies.",
    "Hardware components face supply chain constraints globally.",
    "Development tools market grows with remote work trends.",
    "AI research requires significant computational resources.",
    "Quarterly reports show mixed results across tech sector.",
    "Stock market analysts upgrade technology sector ratings.",
    "Cloud computing adoption accelerates in enterprise market.",
    "Data center construction increases globally.",
    "Semiconductor shortage impacts various industries.",
    "Electric vehicle charging infrastructure expands rapidly.",
    "Software development productivity tools gain popularity.",
    "Machine learning frameworks become more accessible.",
    "Enterprise software licensing models evolve.",
    "Technology conferences showcase latest innovations."
]

print(f"Created {len(chunks)} sample chunks for demonstration")
# Out:
# Created 60 sample chunks for demonstration

# %%
# Convert to Document objects
documents = [Document(page_content=chunk, metadata={"source": f"chunk_{i}"}) for i, chunk in enumerate(chunks)]

# %%
from llms import get_embedding_model


db = Chroma.from_documents(
    documents,
    embedding=get_embedding_model(),
    collection_metadata={"hnsw:space": "cosine"}
)

vector_retriever = db.as_retriever(search_type="similarity", search_kwargs={"k": 15})

# %%
bm25_retriever = BM25Retriever.from_documents(documents, k=15)

# %%
hybrid_retriever = EnsembleRetriever(
    retrievers=[vector_retriever, bm25_retriever],
    weights=[0.7, 0.3],
)

# %%
query = "Tesla financial performance and production updates"

print("STEP 1: Hybrid Search Results")
print("-"*50)

retrieved_docs = hybrid_retriever.invoke(query)  # Get top 25 for reranking

# Show top 10 from hybrid search
for i, doc in enumerate(retrieved_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print(f"\n(Retrieved {len(retrieved_docs)} total chunks for reranking)\n")
# Out:
# STEP 1: Hybrid Search Results
# --------------------------------------------------
#  1. Tesla reported strong free cash flow generation of $7.5 billion.
#  2. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#  3. Tesla stock price reached new highs following earnings announcement.
#  4. Tesla's automotive gross margin improved to 19.3% this quarter.
#  5. Tesla's Full Self-Driving revenue increased significantly.
#  6. Tesla announced plans to expand Gigafactory production capacity.
#  7. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#  8. The Tesla coil was invented by Nikola Tesla in 1891.
#  9. Tesla Model Y became the best-selling vehicle worldwide.
# 10. Tesla continues to lead in electric vehicle market share globally.
# 11. Electric vehicle charging infrastructure expands rapidly.
# 12. Technology conferences showcase latest innovations.
# 13. Machine learning frameworks become more accessible.
# 14. Enterprise software licensing models evolve.
# 15. Development tools market grows with remote work trends.
# 16. Hardware components face supply chain constraints globally.
# 17. Financial markets showed volatility during earnings season.
#
# (Retrieved 17 total chunks for reranking)

# %%
print("STEP 2: After Cohere Reranking (Top 10)")
print("-"*50)

# Initialize Cohere reranker
reranker = CohereRerank(model="rerank-english-v3.0", top_n=10)

# Rerank the retrieved documents
reranked_docs = reranker.compress_documents(retrieved_docs, query)

# Show reranked results
for i, doc in enumerate(reranked_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print("\n" + "="*80)
print("ANALYSIS:")
print("✅ Hybrid Search: Mixed relevant and irrelevant results")
print("✅ Reranking: Most relevant Tesla financial/production info at top")
print("✅ Notice how reranking moved the most contextually relevant chunks higher")

# Optional: Show the difference more clearly
print("\n" + "="*80)
print("KEY IMPROVEMENTS AFTER RERANKING:")
print("-"*40)


hybrid_top_5 = [doc.page_content for doc in retrieved_docs[:5]]
reranked_top_5= [doc.page_content for doc in reranked_docs[:5]]

print("BEFORE (Hybrid Top 3):")
for i, content in enumerate(hybrid_top_5, 1):
    print(f"  {i}. {content}")

print("\nAFTER (Reranked Top 3):")
for i, content in enumerate(reranked_top_5, 1):
    print(f"  {i}. {content}")
# Out:
# STEP 2: After Cohere Reranking (Top 10)
# --------------------------------------------------
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[40], line 5
#       1 print("STEP 2: After Cohere Reranking (Top 10)")
#       2 print("-"*50)
#       3
#       4 # Initialize Cohere reranker
# ----> 5 reranker = CohereRerank(model="rerank-english-v3.0", top_n=10)
#       6
#       7 # Rerank the retrieved documents
#       8 reranked_docs = reranker.compress_documents(retrieved_docs, query)
#
#     [... skipping hidden 1 frame]
#
# File ~/home/ensimag/mini-rag-project/venv/lib/python3.14/site-packages/langchain_cohere/rerank.py:53, in CohereRerank.validate_environment(self)
#      51         cohere_api_key = self.cohere_api_key
#      52     client_name = self.user_agent
# ---> 53     self.client = cohere.ClientV2(
#      54         cohere_api_key,
#      55         client_name=client_name,
#      56         base_url=self.base_url,
#      57     )
#      58 elif not isinstance(self.client, cohere.ClientV2):
#      59     raise ValueError(
#      60         "The 'client' parameter must be an instance of cohere.ClientV2.\n"
#      61         "You may create the ClientV2 object like:\n\n"
#      62         "import cohere\nclient = cohere.ClientV2(...)"
#      63     )
#
# File ~/home/ensimag/mini-rag-project/venv/lib/python3.14/site-packages/cohere/client_v2.py:45, in ClientV2.__init__(self, api_key, base_url, environment, client_name, timeout, httpx_client, thread_pool_executor, log_warning_experimental_features)
#      32 def __init__(
#      33     self,
#      34     api_key: typing.Optional[typing.Union[str,
#    (...)     43     log_warning_experimental_features: bool = True,
#      44 ):
# ---> 45     Client.__init__(
#      46         self,
#      47         api_key=api_key,
#      48         base_url=base_url,
#      49         environment=environment,
#      50         client_name=client_name,
#      51         timeout=timeout,
#      52         httpx_client=httpx_client,
#      53         thread_pool_executor=thread_pool_executor,
#      54         log_warning_experimental_features=log_warning_experimental_features,
#      55     )
#      56     v1_raw = self._raw_client
#      57     V2Client.__init__(
#      58         self,
#      59         client_wrapper=self._client_wrapper
#      60     )
#
# File ~/home/ensimag/mini-rag-project/venv/lib/python3.14/site-packages/cohere/client.py:153, in Client.__init__(self, api_key, base_url, environment, client_name, timeout, httpx_client, thread_pool_executor, log_warning_experimental_features)
#     149 base_url = fix_base_url(base_url)
#     151 self._executor = thread_pool_executor
# --> 153 BaseCohere.__init__(
#     154     self,
#     155     base_url=base_url,
#     156     environment=environment,
#     157     client_name=client_name,
#     158     token=api_key,
#     159     timeout=timeout,
#     160     httpx_client=httpx_client,
#     161 )
#     163 validate_args(self, "chat", throw_if_stream_is_true)
#     164 if log_warning_experimental_features:
#
# File ~/home/ensimag/mini-rag-project/venv/lib/python3.14/site-packages/cohere/base_client.py:127, in BaseCohere.__init__(self, base_url, environment, client_name, token, headers, timeout, follow_redirects, httpx_client, logging)
#     123 _defaulted_timeout = (
#     124     timeout if timeout is not None else 300 if httpx_client is None else httpx_client.timeout.read
#     125 )
#     126 if token is None:
# --> 127     raise ApiError(body="The client must be instantiated be either passing in token or setting CO_API_KEY")
#     128 self._client_wrapper = SyncClientWrapper(
#     129     base_url=_get_base_url(base_url=base_url, environment=environment),
#     130     client_name=client_name,
#    (...)    139     logging=logging,
#     140 )
#     141 self._raw_client = RawBaseCohere(client_wrapper=self._client_wrapper)
#
# ApiError: headers: None, status_code: None, body: The client must be instantiated be either passing in token or setting CO_API_KEY
